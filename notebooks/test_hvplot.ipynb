# %%
# Test if hvplot works at all
import pandas as pd
import hvplot.pandas
import panel as pn

pn.extension()

# Create simple test data
df = pd.DataFrame({
    'x': [1, 2, 3, 4, 5],
    'y': [2, 4, 6, 8, 10],
    'category': ['A', 'B', 'A', 'B', 'A']
})

print("Data loaded:")
print(df)
print("\nCreating plot...")

# Try to create a simple plot
df.hvplot.line(x='x', y='y', by='category', width=600, height=400)
