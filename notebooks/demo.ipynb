# %% [markdown]
# # Panel Starter - Demo Notebook
#
# This notebook demonstrates how to use the Panel application in a Jupyter environment.

# %% [markdown]
# ## Setup
#
# First, let's install the package (if not already installed) and import the necessary modules.

# %%
# Install the package in development mode
# Uncomment if not already installed
# !pip install -e ..
# Out:
# Obtaining file:///C:/Users/spenc/Downloads/study-llm/study-query-llm
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: panel>=1.3.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from study-query-llm==0.1.0) (1.8.1)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from study-query-llm==0.1.0) (2.3.1)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from study-query-llm==0.1.0) (2.2.4)
# Requirement already satisfied: hvplot>=0.9.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from study-query-llm==0.1.0) (0.12.1)
# Requirement already satisfied: jupyter in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from study-query-llm==0.1.0) (1.1.1)
# Requirement already satisfied: jupyterlab>=3.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from study-query-llm==0.1.0) (4.4.5)
# Requirement already satisfied: param>=2.0.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from study-query-llm==0.1.0) (2.2.1)
# Requirement already satisfied: bokeh>=3.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from hvplot>=0.9.0->study-query-llm==0.1.0) (3.8.0)
# Requirement already satisfied: colorcet>=2 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from hvplot>=0.9.0->study-query-llm==0.1.0) (3.1.0)
# Requirement already satisfied: holoviews>=1.19.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from hvplot>=0.9.0->study-query-llm==0.1.0) (1.21.0)
# Requirement already satisfied: packaging in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from hvplot>=0.9.0->study-query-llm==0.1.0) (24.2)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (3.1.6)
# Requirement already satisfied: jupyter-core in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (79.0.1)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (6.4.2)
# Requirement already satisfied: traitlets in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab>=3.0->study-query-llm==0.1.0) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from pandas>=1.5.0->study-query-llm==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from pandas>=1.5.0->study-query-llm==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from pandas>=1.5.0->study-query-llm==0.1.0) (2025.2)
# Requirement already satisfied: bleach in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (6.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (2.0.3)
# Requirement already satisfied: markdown in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (3.9)
# Requirement already satisfied: markdown-it-py in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (0.5.0)
# Requirement already satisfied: pyviz-comms>=2.0.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (3.0.6)
# Requirement already satisfied: requests in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from panel>=1.3.0->study-query-llm==0.1.0) (4.13.0)
# Requirement already satisfied: notebook in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter->study-query-llm==0.1.0) (7.4.5)
# Requirement already satisfied: jupyter-console in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter->study-query-llm==0.1.0) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter->study-query-llm==0.1.0) (7.16.6)
# Requirement already satisfied: ipywidgets in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter->study-query-llm==0.1.0) (8.1.7)
# Requirement already satisfied: contourpy>=1.2 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from bokeh>=3.1->hvplot>=0.9.0->study-query-llm==0.1.0) (1.3.1)
# Requirement already satisfied: narwhals>=1.13 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from bokeh>=3.1->hvplot>=0.9.0->study-query-llm==0.1.0) (2.5.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from bokeh>=3.1->hvplot>=0.9.0->study-query-llm==0.1.0) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from bokeh>=3.1->hvplot>=0.9.0->study-query-llm==0.1.0) (6.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from bokeh>=3.1->hvplot>=0.9.0->study-query-llm==0.1.0) (2025.4.0)
# Requirement already satisfied: anyio in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from httpx>=0.25.0->jupyterlab>=3.0->study-query-llm==0.1.0) (4.9.0)
# Requirement already satisfied: certifi in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from httpx>=0.25.0->jupyterlab>=3.0->study-query-llm==0.1.0) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from httpx>=0.25.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.0.7)
# Requirement already satisfied: idna in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from httpx>=0.25.0->jupyterlab>=3.0->study-query-llm==0.1.0) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (9.0.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.6.0)
# Requirement already satisfied: psutil in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (26.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jinja2>=3.0.3->jupyterlab>=3.0->study-query-llm==0.1.0) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-core->jupyterlab>=3.0->study-query-llm==0.1.0) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-core->jupyterlab>=3.0->study-query-llm==0.1.0) (310)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=3.0->study-query-llm==0.1.0) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=3.0->study-query-llm==0.1.0) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=3.0->study-query-llm==0.1.0) (4.23.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from nbconvert->jupyter->study-query-llm==0.1.0) (4.13.3)
# Requirement already satisfied: defusedxml in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from nbconvert->jupyter->study-query-llm==0.1.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from nbconvert->jupyter->study-query-llm==0.1.0) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from nbconvert->jupyter->study-query-llm==0.1.0) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from nbconvert->jupyter->study-query-llm==0.1.0) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from nbconvert->jupyter->study-query-llm==0.1.0) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from nbconvert->jupyter->study-query-llm==0.1.0) (2.19.1)
# Requirement already satisfied: webencodings in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from bleach->panel>=1.3.0->study-query-llm==0.1.0) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->study-query-llm==0.1.0) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from requests->panel>=1.3.0->study-query-llm==0.1.0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from requests->panel>=1.3.0->study-query-llm==0.1.0) (2.3.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipywidgets->jupyter->study-query-llm==0.1.0) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipywidgets->jupyter->study-query-llm==0.1.0) (3.0.15)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-console->jupyter->study-query-llm==0.1.0) (3.0.50)
# Requirement already satisfied: uc-micro-py in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from linkify-it-py->panel>=1.3.0->study-query-llm==0.1.0) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from markdown-it-py->panel>=1.3.0->study-query-llm==0.1.0) (0.1.2)
# Requirement already satisfied: colorama in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from tqdm->panel>=1.3.0->study-query-llm==0.1.0) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (21.2.0)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->study-query-llm==0.1.0) (1.4.0)
# Requirement already satisfied: decorator in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.19.2)
# Requirement already satisfied: stack_data in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=3.0->study-query-llm==0.1.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=3.0->study-query-llm==0.1.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=3.0->study-query-llm==0.1.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=3.0->study-query-llm==0.1.0) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (3.3.0)
# Requirement already satisfied: rfc3339-validator in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->study-query-llm==0.1.0) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->study-query-llm==0.1.0) (2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.8.4)
# Requirement already satisfied: fqdn in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.17.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab>=3.0->study-query-llm==0.1.0) (0.2.3)
# Requirement already satisfied: pycparser in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\spenc\.conda\envs\ucf\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3.0->study-query-llm==0.1.0) (2.9.0.20241206)
# Installing collected packages: study-query-llm
#   Attempting uninstall: study-query-llm
#     Found existing installation: study-query-llm 0.1.0
#     Uninstalling study-query-llm-0.1.0:
#       Successfully uninstalled study-query-llm-0.1.0
#   Running setup.py develop for study-query-llm
# Successfully installed study-query-llm-0.1.0
#   DEPRECATION: Legacy editable install of study-query-llm==0.1.0 from file:///C:/Users/spenc/Downloads/study-llm/study-query-llm (setup.py develop) is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457

# %%
import panel as pn
import pandas as pd
import numpy as np
import hvplot.pandas
# Enable Panel extensions
pn.extension('tabulator', design='material')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='837e06ae-5590-47b0-aea7-b67064dba0ce'>
#   <div id="c0b4384f-c1df-4008-8d07-9402ec3c4df0" data-root-id="837e06ae-5590-47b0-aea7-b67064dba0ce" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"93b61312-c720-466f-a249-1582f39b535d":{"version":"3.8.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"16202a40-f68f-4b5a-adef-3ab40e87dc7c","attributes":{"notifications":{"type":"object","name":"Notifications","id":"b45926a0-f748-4d0a-9c1c-baace7ab365c"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"837e06ae-5590-47b0-aea7-b67064dba0ce"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"76b60ddc-8e71-43c7-bd65-95cc621e4817","attributes":{"plot_id":"837e06ae-5590-47b0-aea7-b67064dba0ce","comm_id":"71e8de01b3a24940b8352fe923bae976","client_comm_id":"7bc1d26141584885979cf95896da0f51"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"93b61312-c720-466f-a249-1582f39b535d","roots":{"837e06ae-5590-47b0-aea7-b67064dba0ce":"c0b4384f-c1df-4008-8d07-9402ec3c4df0"},"root_ids":["837e06ae-5590-47b0-aea7-b67064dba0ce"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## Load the Application
#
# Now let's import and create our application.

# %%
import sys
from pathlib import Path

repo_root = Path.cwd().parent  # notebooks/ -> project root
if repo_root not in map(Path, sys.path):
    sys.path.append(str(repo_root))

from panel_app.app import create_app

# Create the app
app = create_app()

# Display in the notebook
app.servable()

# %% [markdown]
# ## Working with Components Separately
#
# You can also work with individual components of the application.

# %%
from panel_app.utils.data_loader import load_sample_data
from panel_app.components.dashboard import Dashboard

# Load data
data = load_sample_data()
data.head()

# %%
# Create dashboard component
dashboard = Dashboard(data)

# Display just the plot
dashboard.create_plot()

# %%
# Display the statistics
dashboard.create_stats()

# %% [markdown]
# ## Creating Custom Visualizations
#
# You can create your own visualizations using the data.

# %%
# Create a custom plot
custom_plot = data.hvplot.scatter(
    x='revenue', 
    y='profit', 
    c='region',
    size='customers',
    title='Revenue vs Profit by Region',
    width=700,
    height=400
)

custom_plot

# %% [markdown]
# ## Interactive Widgets
#
# Create interactive widgets that update visualizations in real-time.

# %%
# Create interactive widgets
column_select = pn.widgets.Select(
    name='Select Column',
    options=['sales', 'revenue', 'profit', 'satisfaction'],
    value='sales'
)

@pn.depends(column_select.param.value)
def update_plot(column):
    return data[column].hvplot.hist(
        title=f'Distribution of {column}',
        width=600,
        height=400
    )

# Create layout
pn.Row(
    column_select,
    update_plot
)

# %% [markdown]
# ## Deploying from Notebook
#
# To deploy this notebook as a standalone app, run:
#
# ```bash
# panel serve demo.ipynb --show
# ```
#
# Or use the Panel preview button in JupyterLab.

# %% [markdown]
# ## Next Steps
#
# - Modify the components in `panel_app/components/`
# - Add new data sources in `panel_app/utils/`
# - Customize the template in `panel_app/app.py`
# - Deploy to production using Docker or cloud services
